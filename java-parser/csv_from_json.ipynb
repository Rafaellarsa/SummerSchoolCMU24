# %%
import json
import pandas as pd

with open('output.json', 'r') as json_file:
    data = pd.read_json(json_file)



# df = pd.DataFrame.from_records(data)


# df.head()

data
# Out:
#                                                         0
# 0       {"sline":0,"concept":"ClassDefinition","eline"...
# 1       {"sline":0,"concept":"PublicClassSpecifier","e...
# 2       {"sline":0,"concept":"MethodDefinition","eline...
# 3       {"sline":0,"concept":"PublicMethodSpecifier","...
# 4       {"sline":0,"concept":"VoidDataType","eline":0,...
# ...                                                   ...
# 172838  {"sline":12,"concept":"ArrayLength","eline":12...
# 172839  {"sline":12,"concept":"ArrayLength","eline":12...
# 172840  {"sline":12,"concept":"SubtractExpression","el...
# 172841  {"sline":12,"concept":"SimpleAssignmentExpress...
# 172842  {"sline":16,"concept":"ReturnStatement","eline...
#
# [172843 rows x 1 columns]
